# %% [markdown]
# <a href="https://colab.research.google.com/github/AniiEncalada/AED/blob/main/ProyectoML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Proyecto de Machine Learning**

# %% [markdown]
# Flujo de Trabajo:
#
# 1.   Datos y definición del problema
# 2.   Colección de datos
# 2.   Pre procesamiento de datos
# 2.   Análisis de datos y modelamiento supervisado y no supervisado
# 2.   Evaluación

# %% [markdown]
# # 1. Datos y definición del problema

# %% [markdown]
# *   ¿Cuál es el problema que quieres resolver?
#
# En el presente análisis de datos se pretende hacer un estudio a las métricas de facebook sobre una página de venta de cosméticos. Partiendo de que el sitio es una de las formas más comunes entre las estrategias de venta por internet y comunicación con los clientes se tiene en cuenta 19 parámetros que están relacionados con las acciones y reacciones en torno a la página del último año realizadas por sus publicaciones en respuesta a las publicaciones de la FanPage.
#
#
# Sin embargo, y con toda esta información, es necesario poder planificar las próximas acciones en publicaciones, campañas, publicidad y enganche hacia el público objetivo con el fin de mejorar ventas y crear relaciones basadas en experiencias de usuario, calidad de servicio y producto así como en satisfacción por el producto. Por tanto, ¿cómo usar toda la información existente para poder establecer las acciones y toma de decisiones en torno al contenido, forma y estrategia a seguirn en la página?
#
# *   ¿Por qué es importante?
#
# Las redes sociales son más que solo una distracción, son una forma de interactuar, conocer y formar parte de comunidad en torno a los temas que son de nuestro interés, dado que ofrecen al mundo diversos mundos y perspectivas acerca de lo mismo. Ahora, se muestran algunas razones por las que dar visibilidad a un negocio en redes sociales es una necesidad del mundo actual.
# **Método y planificación, el social media es una herramienta poderosa para las empresas.** Son “redes” y “sociales”, por lo que lo evidente y significativo de ellas es que permiten a las marcas interactuar de modo directo con clientes potenciales y tener conversaciones inteligentes. En cada red social, una empresa puede generar audiencia, y no cualquier audiencia, sino la adecuada. Debido a que en Internet hay muchísima gente diferente.
# Además de aumentar las ventas de un negocio, **las redes posibilitan fidelizar a sus clientes existentes.** Puede implementar un programa de beneficios, ofrecer material de utilidad, contestar a sus preguntas con videos personalizados o ser simplemente atento, con un saludo de cumpleaños o un obsequio a sus promotores.
# Sin seguir con la cantidad de ventajas que se puede obtener **con una buena utilización de redes sociales como medio de estar más cerca del cliente y de mostrar productos y servicios de forma interactiva, amigable y estratégica.**

# %% [markdown]
# # 2. Colección de datos

# %%
import pandas as pd #Para el manejo y analisis de estructuras de datos
import matplotlib.pyplot as plt #Para crear graficos en dos dimensiones
import numpy as np
import seaborn as sns #Para generar graficos  

# %matplotlib inline
data = pd.read_csv('https://raw.githubusercontent.com/AniiEncalada/AED/main/dataset_Facebook.csv')
data.head(10)
# Out:
#    Total de likes    Tipo  Categoría  ...  Me gusta  Compartido  Total interacciones
# 0          139441   Photo          2  ...      79.0        17.0                  100
# 1          139441  Status          2  ...     130.0        29.0                  164
# 2          139441   Photo          3  ...      66.0        14.0                   80
# 3          139441   Photo          2  ...    1572.0       147.0                 1777
# 4          139441   Photo          2  ...     325.0        49.0                  393
# 5          139441  Status          2  ...     152.0        33.0                  186
# 6          139441   Photo          3  ...     249.0        27.0                  279
# 7          139441   Photo          3  ...     325.0        14.0                  339
# 8          139441  Status          2  ...     161.0        31.0                  192
# 9          139441   Photo          3  ...     113.0        26.0                  142
#
# [10 rows x 19 columns]

# %% [markdown]
# *   ¿Qué datos te ayudan a resolver el problema?
#
#
#
# **Tipo**	Tipo de publicación (foto, estado, enlace, video)	- Determinar los tipos de publicaciones y frecuencia
#
#
#
# Saber la frecuencia de publicación en el tiempo
#
# **Mes de publicación**	Mes del año en que se hizo la publicación
#
#
#
# **Pagado**	Publicación con publicidad pagada (1: pagado, 0: orgánico) -	Saber que tan orgánica es la audiencia
#
#
# **Alcance total de publicación por vida**	Alcance de una publicación a lo largo del tiempo	- Determinar cuál es el alcance que se logra con las publicaciones
#
#
#
#
# **Usuarios comprometidos de por vida**	Usuarios que se han comprometido con el sitio a lo largo de una publicación	- Saber el nivel de enganche de las publicaciones
#
#
# **Consumidores totales por vida**	Comsumidores de una publicación a lo largo del tiempo	- Determinar a cuantas personas se llegó con una publicación
#
#
#
# Estadísticas relacionadas con la audiencia que ya le ha dado le gusta a la página y las reacciones frente a las publicaciones
#
# **Alcance de publicaciones en personas a las que le gusta la página**	Alcance de publicaciones sobre las personas que le han dado me gusta a la página
#
#
# Interacciones de la audiencia con las publicaciones
# **Total interacciones**	Total de interacciones hacia una publicación
#
#     Comentarios	Comentarios recibidos a una publicación	Interacciones de la audiencia con las publicaciones
#
#     Me gusta	Reacciones recibidos a una publicación
#
#     Compartido	Veces que se ha compartido una publicación
#
# *   ¿Puedes recuperar los datos e fuentes existentes?

# %% [markdown]
# # 3. Pre procesamiento de datos

# %% [markdown]
# *   Limpieza de datos
# *   Completar valores faltantes
# *   Normalizar
# *   Eliminar valores atípicos
# *   Codificación
# *   Entre otros
#
# **Tipos de variables**
# * Numéricas
#   * Total de likes
#   * Alcance total de publicación por vida
#   * Impresiones totales de publicación por vida
#   * Usuarios comprometidos de por vida
#   * Consumidores totales por vida
#   * Consumo de publicaciones de por vida
#   * Impresiones de publicaciones en personas a las que le gusta la página
#   * Alcance de publicaciones en personas a las que le gusta la página
#   * Personas que les gusta la página y participan de publicación
#   * Comentarios
#   * Me gusta
#   * Compartido
#   * Total interacciones
# * Ordinales
#   * Mes de publicación
#   * Semana de publicación
#   * Hora de publicacición
# * Categórica
#   * Tipo
#   * Categoría
#   * Pagado

# %% [markdown]
# # 4. Análisis de datos y modelamiento supervisado y no supervisado

# %% [markdown]
# 1.   Análisis Exploratorio de Datos
# 2.   Algoritmos de aprendizaje supervisado (clasificación y regresión)
# 2.   Algoritmos de aprendizaje no supervisado (agrupamiento y reglas de asociación)

# %% [markdown]
# ## 4.1. Análisis exploratorio de datos

# %% [markdown]
# ### Limpieza de datos

# %%
print("¿Hay datos nulos?")
print(data.isna().sum().sort_values())
data = data.fillna(0)
# Out:
# ¿Hay datos nulos?
# Total de likes                                                           0
# Comentarios                                                              0
# Personas que les gusta la página y participan de publicación             0
# Alcance de publicaciones en personas a las que le gusta la página        0
# Impresiones de publicaciones en personas a las que le gusta la página    0
# Consumo de publicaciones de por vida                                     0
# Consumidores totales por vida                                            0
# Impresiones totales de publicación por vida                              0
# Usuarios comprometidos de por vida                                       0
# Hora de publicación                                                      0
# Semana de publicación                                                    0
# Mes de publicación                                                       0
# ...

# %% [markdown]
# ### Total de likes en la página
#
# En los datos obtenidos de la página se puede evidenciar el crecimiento de la página en cuanto a seguidores y gente a la que le gusta. Para mayor claridad de lo expuesto ¿cuál es la diferencia entre el mínimo y máximo del **Total de likes en la página**?

# %%
data['Total de likes'].describe()
plt.hist(x=data['Total de likes'], color='#3ED9CA', rwidth=0.85)
plt.title('Total de likes')
plt.xlabel('Total de likes')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

# %%
minimo = data['Total de likes'].min()
maximo = data['Total de likes'].max()
print("En crecimiento de los seguidores de la página ha sido de: ", abs(maximo-minimo))
# Out:
# En crecimiento de los seguidores de la página ha sido de:  58071

# %% [markdown]
# ### Tipo de publicación
# **¿Qué tipo de publicación ha predominado en la página?**
#
# Haciendo un análisis al **Tipo** de publicación que ha hecho con mayor frecuencia, conociendo que solo se han clasificado en 4 tipos: *Foto, Estado, Enlace y Vídeo*, se puede observar que el tipo “**Foto**” ha sido el más destacado por mucho entre otros tipos, ya que de 500 publicaciones **426** corresponden a este tipo, **45** corresponden a “**Estados**”, **22** a “**Enlaces**” y, solamente, **7** a “**Vídeos**”

# %%
data['Tipo'].describe()
# Out:
# count       500
# unique        4
# top       Photo
# freq        426
# Name: Tipo, dtype: object

# %%
plt.pie(data['Tipo'].value_counts(), shadow=True, autopct="%0.1f %%", labels=['Foto','Estado', 'Enlace', 'Vídeo'], colors=["#99DBAD", "#ECBBBA",  "#F7D31E","#ffffff"])
plt.show()

# %% [markdown]
# ### Media
# ¿Cuál es la media de **comentarios, me gusta, compartidos y el total de interacciones** de las publicaciones?

# %%
data['Comentarios'].mean() # Media de comentarios
# Out:
# 7.482

# %%
data['Me gusta'].mean() #Media de Me gusta
# Out:
# 177.59

# %%
data['Compartido'].mean() #Media de compartidos
# Out:
# 27.048

# %%
data['Total interacciones'].mean() #Media de total de interacciones
# Out:
# 212.12

# %% [markdown]
# ### Publicaciones promocionadas u orgánicas
#
# **¿La tendencia en las publicaciones se ha destacado por ser pagadas u orgánicas?**

# %%
plt.pie(data['Pagado'].value_counts(), shadow=True, autopct="%0.1f %%", labels=['Orgánico','Pagado'], colors=["#BFD1D4", "#ECBBBA"])
plt.show()

# %% [markdown]
# ### Interacción con publicaciones
#
# ¿Cómo se distribuyen los datos de interacciones con las publicaciones de la página?
#
# A continuación se hará uso de **histogramas** para ver los datos correspondientes a **cometarios, me gusta, compartidos y total de interacciones** en las publicaciones

# %%
plt.hist(x=data['Comentarios'], color='#ECBBBA', rwidth=0.85)
plt.title('Comentarios')
plt.xlabel('Comentarios')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

# %%
plt.hist(x=data['Me gusta'], color='#BFD1D4', rwidth=0.85)
plt.title('Me gusta')
plt.xlabel('Me gusta')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

# %%
plt.hist(x=data['Compartido'], color='#99DBAD', rwidth=0.85)
plt.title('Compartido')
plt.xlabel('Compartido')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

# %%
plt.hist(x=data['Total interacciones'], color='#F7D31E', rwidth=0.85)
plt.title('Total de interacciones')
plt.xlabel('Total de interacciones')
plt.ylabel('Frecuencia')

plt.show() #dibujamos el histograma

# %% [markdown]
# ### Análisis de alcance e interacciones
# ¿Donde se ubica la mayor parte de los valores del total de **likes en la página, alcance total en la vida de la publicación y del total de interacciones con las publicaciones**?

# %%
data.boxplot(column='Total de likes') #Se encuentran entre 81000 y 137000

# %%
data.boxplot(column='Alcance total de publicación por vida') #Su distribución es muy variada

# %%
data.boxplot(column='Total interacciones') #Su distribución es muy variada

# %% [markdown]
# ¿Existe una relación directamente proporcional entre **comentarios y me gusta** de una publicación?

# %%
fig, ax = plt.subplots()
ax.scatter(data['Comentarios'], data['Me gusta'])
plt.show()
#Son proporcionales, ya que a más likes, más comentarios.
#En redes sociales, esto responde a que cuando se genera mayor interacciones, las publicaciones se imprimen en 
#repetidas veces a los mismo usuarios y crea una tendencia de reacción

# %% [markdown]
# ¿Hay alguna relación entre el **Alcance total de publicación por vida** con las
# **Impresiones totales de publicación por vida**?

# %%
fig, ax = plt.subplots()
ax.scatter(data['Impresiones totales de publicación por vida'], data['Alcance total de publicación por vida'])
plt.show()
#Guardan estrecha relación dado que a que mayor impresiones, la posibilidad de mejor alcance aumenta

# %% [markdown]
# **¿Se ha logrado una mejor interacción con las publicaciones pagadas respecto a las órganicas?**
#
# Se observa que en efecto, las publicaciones tienen una mejor interacción, esto puede responder a que se mejora el alcance llegando a otros públicos. Adicional se adjunta la comparación entre **Impresión de publicaciones respecto a si es pagada o no**

# %%
data[['Pagado','Total interacciones']].groupby(['Pagado']).mean().plot.bar(color=("#67BAAD"))
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
data[['Pagado','Impresiones totales de publicación por vida']].groupby(['Pagado']).mean().plot.bar(color=("#67BAAD"))
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# **¿El tipo de publicación a mejorado o disminuido el total de interacciones?**
#
# El tipo de publicación vídeo tiene una mejor interacción, pero se debe tener en cuenta en es el tipo de publicación menos frecuente de la página por lo que no se puede considerar como fiable en la toma de decisiones que determine qué contenido seguir publicando

# %%
data[['Tipo','Total interacciones']].groupby(['Tipo']).mean().plot.bar(color=("#67BAAD"))
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# **¿Qué tipo de publicación a llegado a más comsumidores de publicaciones de por vida?**
#
# Esto puede ayudar a determinar que tipo de publicación atrae más a la audiencia. En campañas de relaciones públicas, sirve mucho conocer el tipo de publicación que más agrada a la audiencia para enfocar la estrategia sobre este tipo de contenido sin perder la imagen comunicacional que ha caracterizado al sitio.

# %%
data[['Tipo','Consumidores totales por vida']].groupby(['Tipo']).mean().plot.bar(color=("#67BAAD"))
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# **¿Cuál es la relación entre consumidores alcanzados de forma orgánica frente a los pagados?**

# %%
data[['Pagado','Consumidores totales por vida']].groupby(['Pagado']).mean().plot.bar(color=("#67BAAD"))
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# **¿Cuál es la relación  entre el tipo de publicación y la decisión de pagar publicidad o no?**

# %%
#Pagado: {0: orgánico 1: Pagado}
pd.crosstab(data['Tipo'], data['Pagado'], margins = True).style.background_gradient(cmap = 'summer_r')
# Out:
# <style  type="text/css" >
# #T_453ea8b4_04dc_11ec_8c70_0242ac1c0002row0_col0{
#             background-color:  #f6fa66;
#             color:  #000000;
#         }#T_453ea8b4_04dc_11ec_8c70_0242ac1c0002row0_col1{
#             background-color:  #fcfe66;
#             color:  #000000;
#         }#T_453ea8b4_04dc_11ec_8c70_0242ac1c0002row0_col2{
#             background-color:  #f8fc66;
#             color:  #000000;
#         }#T_453ea8b4_04dc_11ec_8c70_0242ac1c0002row1_col0,#T_453ea8b4_04dc_11ec_8c70_0242ac1c0002row1_col2{
#             background-color:  #269266;
#             color:  #000000;
#         }#T_453ea8b4_04dc_11ec_8c70_0242ac1c0002row1_col1{
#             background-color:  #259266;
#             color:  #000000;
#         }#T_453ea8b4_04dc_11ec_8c70_0242ac1c0002row2_col0{
#             background-color:  #e9f466;
#             color:  #000000;
#         }#T_453ea8b4_04dc_11ec_8c70_0242ac1c0002row2_col1{
#             background-color:  #f4fa66;
# ...

# %% [markdown]
# **¿Cuál es el tipo de publicación mejor distribuido entre las categorías de
# publicación?**

# %%
pd.crosstab(data['Tipo'], data['Categoría'], margins = True).style.background_gradient(cmap = 'summer_r')
# Out:
# <style  type="text/css" >
# #T_45488668_04dc_11ec_8c70_0242ac1c0002row0_col0{
#             background-color:  #ebf566;
#             color:  #000000;
#         }#T_45488668_04dc_11ec_8c70_0242ac1c0002row0_col1,#T_45488668_04dc_11ec_8c70_0242ac1c0002row0_col2{
#             background-color:  #fefe66;
#             color:  #000000;
#         }#T_45488668_04dc_11ec_8c70_0242ac1c0002row0_col3{
#             background-color:  #f8fc66;
#             color:  #000000;
#         }#T_45488668_04dc_11ec_8c70_0242ac1c0002row1_col0{
#             background-color:  #249266;
#             color:  #000000;
#         }#T_45488668_04dc_11ec_8c70_0242ac1c0002row1_col1{
#             background-color:  #4ca666;
#             color:  #000000;
#         }#T_45488668_04dc_11ec_8c70_0242ac1c0002row1_col2{
#             background-color:  #088466;
#             color:  #f1f1f1;
#         }#T_45488668_04dc_11ec_8c70_0242ac1c0002row1_col3{
#             background-color:  #269266;
# ...

# %%
# actualizando los elementos diagonales en un diagrama de par para mostrar un kde
#sns.pairplot(data, hue="Tipo",diag_kind="kde")

# %%
# Grafico de la longitud de petalo para cada especie o clase 
sns.violinplot(data=data,x="Tipo", y="Total de likes")

# %%
sns.violinplot(data=data,x="Tipo", y="Total interacciones")

# %%
# Importando métricas para evaluación
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
# Separando los datos en variables dependientes e independientes
X = data.drop(["Total de likes",
               "Tipo",
               "Categoría",
               "Semana de publicación",
               "Hora de publicación",
               "Impresiones totales de publicación por vida",
               "Consumo de publicaciones de por vida",
               "Impresiones de publicaciones en personas a las que le gusta la página",
               "Personas que les gusta la página y participan de publicación",
               "Comentarios",
               "Me gusta",
               "Compartido"], axis = 'columns')
y = data["Tipo"]

# Dividiendo el dataset en entrenamiento y prueba
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# ## 4.2. Algoritmos de aprendizaje supervisado (clasificación y regresión)

# %% [markdown]
# ### Regresión logística
# ![image.png](data:image/png;base64,...)
#
# Es un tipo de análisis de regresión utilizado para predecir el resultado de una variable categórica (una variable que puede adoptar un número limitado de categorías) en función de las variables independientes o predictoras. Es útil para modelar la probabilidad de un evento ocurriendo en función de otros factores. El análisis de regresión logística se enmarca en el conjunto de Modelos Lineales Generalizados (GLM) que usa como función de enlace la función logit. Las probabilidades que describen el posible resultado de un único ensayo se modelan como una función de variables explicativas, utilizando una función logística.
# Puede usarse para aproximar la probabilidad de que ocurra cierto suceso o no ocurra el suceso de acuerdo al valor de las variable explicativas.

# %%
# Regresión Logística
from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(X_train, y_train)

y_pred = classifier.predict(X_test)

# Resumen de las predicciones hechas por el clasificador
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Precisión
from sklearn.metrics import accuracy_score
print('accuracy is',accuracy_score(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#         Link       0.00      0.00      0.00         6
#        Photo       0.89      0.85      0.87        86
#       Status       0.21      0.38      0.27         8
#        Video       0.00      0.00      0.00         0
#
#     accuracy                           0.76       100
#    macro avg       0.28      0.31      0.29       100
# weighted avg       0.78      0.76      0.77       100
#
# [[ 0  5  0  1]
#  [ 2 73 11  0]
#  [ 1  4  3  0]
#  [ 0  0  0  0]]
# accuracy is 0.76
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
data_predecir = pd.read_csv('/content/dataset_Facebook_predecir.csv')
data_predecir.head()
# Out:
#    Mes de publicación  ...  Total interacciones
# 0                  10  ...                 2500
# 1                  11  ...                 2500
# 2                  12  ...                 2500
#
# [3 rows x 7 columns]

# %%
ar = pd.DataFrame({"Mes de publicación": [10],	"Pagado": [1],	"Alcance total de publicación por vida": [80000],	
                   "Usuarios comprometidos de por vida": [3000],	"Consumidores totales por vida": [2000],	
                   "Alcance de publicaciones en personas a las que le gusta la página": [35000],	"Total interacciones": [2500]})

y_pred = classifier.predict(ar)
y_pred
# Out:
# array(['Photo'], dtype=object)

# %% [markdown]
# ### Naive Bayes
# ![image.png](data:image/png;base64,...)
#
# Se basan en una técnica de clasificación estadística llamada “teorema de Bayes”, se llaman algoritmos “Naive” que se traduce como “Inocentes”. En ellos se asume que las variables predictoras son independientes entre sí; es decir, que la presencia de una cierta característica en un conjunto de datos no está en absoluto relacionada con la presencia de cualquier otra característica.
# Este algoritmo calcula la probabilidad de que ocurra un cierto evento A, dadas algunas probabilidades de eventos ‘anteriores’.

# %%
# Naive Bayes
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train, y_train)

y_pred = classifier.predict(X_test)

# Resumen de las predicciones hechas por el clasificador
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Precisión
from sklearn.metrics import accuracy_score
print('accuracy is',accuracy_score(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#         Link       0.09      0.67      0.16         6
#        Photo       0.94      0.52      0.67        86
#       Status       0.83      0.62      0.71         8
#        Video       0.00      0.00      0.00         0
#
#     accuracy                           0.54       100
#    macro avg       0.46      0.45      0.39       100
# weighted avg       0.88      0.54      0.64       100
#
# [[ 4  2  0  0]
#  [40 45  1  0]
#  [ 1  1  5  1]
#  [ 0  0  0  0]]
# accuracy is 0.54
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
y_pred = classifier.predict(ar)
y_pred
# Out:
# array(['Photo'], dtype='<U6')

# %% [markdown]
# ### Máquinas de Vectores de Soporte
# ![image.png](data:image/png;base64,...)
#
# Para ṕroblemas de clasificación y regresión, dado un conjunto de ejemplos de entrenamiento se puede etiquetar las clases y entrenar una máquina de vectores de soporte (SVM) para construir un modelo que prediga la clase de una nueva muestra. Intuitivamente, una SVM es un modelo que representa a los puntos de muestra en el espacio, separando las clases a 2 espacios lo más amplios posibles mediante un hiperplano de separación definido como el vector entre los 2 puntos, de las 2 clases, más cercanos al que se llama vector soporte. Cuando las nuevas muestras se ponen en correspondencia con dicho modelo, en función de los espacios a los que pertenezcan, pueden ser clasificadas a una o la otra clase.
#
# Más formalmente, una SVM construye un hiperplano o conjunto de hiperplanos en un espacio de dimensionalidad muy alta, o incluso infinita. Una buena separación entre las clases permitirá una clasificación correcta.

# %%
# Support Vector Machine's 

from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)
from sklearn.svm import SVC

classifier = SVC()
classifier.fit(X_train, y_train)

y_pred = classifier.predict(X_test)

# Resumen de las predicciones hechas por el clasificador
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Precisión
from sklearn.metrics import accuracy_score
print('accuracy is',accuracy_score(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#         Link       0.00      0.00      0.00         6
#        Photo       0.86      1.00      0.92        86
#       Status       0.00      0.00      0.00         8
#
#     accuracy                           0.86       100
#    macro avg       0.29      0.33      0.31       100
# weighted avg       0.74      0.86      0.80       100
#
# [[ 0  6  0]
#  [ 0 86  0]
#  [ 0  8  0]]
# accuracy is 0.86
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
y_pred = classifier.predict(ar)
y_pred
# Out:
# array(['Photo'], dtype=object)

# %% [markdown]
# ### K Vecinos más Próximos
# ![image.png](data:image/png;base64,...)
#
# Este es un método de clasificación no paramétrico, que estima el valor de la función de densidad de probabilidad o directamente la probabilidad a posteriori de que un elemento x pertenezca a una clase a partir de la información proporcionada por el conjunto de prototipos. En el proceso de aprendizaje no se hace ninguna suposición acerca de la distribución de las variables predictoras.
#
# En el reconocimiento de patrones, el algoritmo k-nn es usado como método de clasificación de objetos basado en un entrenamiento mediante ejemplos cercanos en el espacio de los elementos. k-nn es un tipo de aprendizaje vago (lazy learning), donde la función se aproxima solo localmente y todo el cómputo es diferido a la clasificación. La normalización de datos puede mejorar considerablemente la exactitud del algoritmo k-nn.

# %%
# K-Nearest Neighbours
from sklearn.neighbors import KNeighborsClassifier

classifier = KNeighborsClassifier(n_neighbors=8)
classifier.fit(X_train, y_train)

y_pred = classifier.predict(X_test)

# Resumen de las predicciones hechas por el clasificador
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Precisión
from sklearn.metrics import accuracy_score
print('accuracy is',accuracy_score(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#         Link       0.00      0.00      0.00         6
#        Photo       0.90      0.95      0.93        86
#       Status       0.56      0.62      0.59         8
#
#     accuracy                           0.87       100
#    macro avg       0.49      0.53      0.50       100
# weighted avg       0.82      0.87      0.84       100
#
# [[ 0  6  0]
#  [ 0 82  4]
#  [ 0  3  5]]
# accuracy is 0.87
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
y_pred = classifier.predict(ar)
y_pred
# Out:
# array(['Photo'], dtype=object)

# %% [markdown]
# ### Árbol de Decisión
# ![image.png](data:image/png;base64,...)
#
# El objetivo de este algoritmo es crear un modelo que prediga el valor de una variable de destino en función de diversas variables de entrada. Cada nodo interior corresponde a una de las variables de entrada; Cada hoja representa un valor de la variable de destino dados los valores de las variables de entrada representados por el camino desde la raíz a la hoja.
#
# Un árbol de decisión es una representación simple para hacer clasificación. El aprendizaje basado en árboles de decisión es una de las técnicas más eficaces para la clasificación supervisada. Para esto, se supone que todas las funciones tienen dominios discretos finitos, y existe una sola característica de destino llamado la clasificación. Cada elemento del dominio de la clasificación se llama clase. Un árbol de decisión o un árbol de clasificación es un árbol en el que cada nodo interno (no hoja) está etiquetado con una función de entrada. Los arcos procedentes de un nodo etiquetado con una característica están etiquetados con cada uno de los posibles valores de la característica. Cada hoja del árbol se marca con una clase o una distribución de probabilidad sobre las clases.
#
# Un árbol puede ser "aprendido" mediante el fraccionamiento del conjunto inicial en subconjuntos basados en una prueba de valor de atributo. Este proceso se repite en cada subconjunto derivado de una manera recursiva llamada particionamiento recursivo. La recursividad termina cuando el subconjunto en un nodo tiene todo el mismo valor de la variable objetivo, o cuando la partición ya no agrega valor a las predicciones.

# %%
# Decision Tree
from sklearn.tree import DecisionTreeClassifier

classifier = DecisionTreeClassifier()

classifier.fit(X_train, y_train)

y_pred = classifier.predict(X_test)

# Resumen de las predicciones hechas por el clasificador
print("Clasificacion")
print("----------------")
print(classification_report(y_test, y_pred))
print("Matriz de confución")
print("----------------")
print(confusion_matrix(y_test, y_pred))
print("Precisión")
print("----------------")
# Precisión
from sklearn.metrics import accuracy_score
print('accuracy is',accuracy_score(y_pred,y_test))
# Out:
# Clasificacion
# ----------------
#               precision    recall  f1-score   support
#
#         Link       0.60      0.50      0.55         6
#        Photo       0.95      0.97      0.96        86
#       Status       0.71      0.62      0.67         8
#        Video       0.00      0.00      0.00         0
#
#     accuracy                           0.91       100
#    macro avg       0.57      0.52      0.54       100
# weighted avg       0.91      0.91      0.91       100
#
# Matriz de confución
# ----------------
# [[ 3  2  1  0]
#  [ 2 83  1  0]
#  [ 0  2  5  1]
#  [ 0  0  0  0]]
# Precisión
# ----------------
# accuracy is 0.91
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
y_pred = classifier.predict(ar)
y_pred
# Out:
# array(['Photo'], dtype=object)

# %% [markdown]
# ## 4.3. Algoritmos de aprendizaje no supervisado

# %% [markdown]
# ### Agrupamiento o Clustering
#
# Medainte este algoritmo se intenta encontrar los centros de los clusters que sean representativos de ciertas regiones de los datos. El algoritmo se alterna tres pasos en su ejecución:
#
# 1. Se determina el número de clusters en los que se quiere dividir los datos. Se asignará un pseudocentro inicial de características $Xc_i$, determinando de forma aleatoria o manualmente, para cada cluster
# 2. Buscar alrededor de cada pseudo-centro los puntos del dataset más cercano.
# 3. Recalcular cada pseudo-centro como la media de los puntos de datos determinada en el punto 2.
#
# El algoritmo finaliza cuando la asignación de instancias a clústeres ya no cambia.
#
# De forma general el algoritmo de **k-means** intenta minimizar la distancia dentro de un cluster y maximizar la distancia entre clusters, para los pseudo-centros iniciales.
#
# En este algoritmo, se separan los grupos en k-grupos de igual varianza mediante un criterio de minimización conocido como la **inercia** o **suma de cuadrados dentro de un cluster**.
#
# El algoritmo de `k-means` divide un conjunto $X$ de $N$ muestras en $K$ clusters $C$ separados, cada uno de ellos descrito por el valor medio $\mu_j$. A estos valores medios se les conoce, comunmente, como "centroides"; tenga en cuenta que estos punto no son, en general, puntos de $X$, aunque pertenecen al mismo espacio.
#
# El algoritmo de `K-means` intenta determinar centroides que minimizan la **inercia**, o **suma de cuadrados dentro de un cluster**:
#
# \begin{equation}
# \sum_{i=0}^n \min_{\mu_j\in C}(||x_i-\mu_j||^2)
# \end{equation}
#
# La inercia se puede pensar como una medida de la coherencia interna de los clústeres. En el ejercicio a desarollar, veremos como usar este factor para determinar un número optimo de $k$ del número de clusters.
#
# En la siguiente animación se ilustra el poroceso iteratívo empleado en k-means para realizar el la agrupación en 4 clusters.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.cluster import KMeans
from sklearn.metrics import pairwise_distances_argmin_min
 
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('ggplot')

# %% [markdown]
# Vemos cuantos registros tenemos en cada `Tipo` de publicación:

# %%
ds = pd.read_csv('https://raw.githubusercontent.com/AniiEncalada/AED/main/dataset_Facebook.csv')
print(ds.groupby('Tipo').size())
# Out:
# Tipo
# Link       22
# Photo     426
# Status     45
# Video       7
# dtype: int64

# %% [markdown]
# Para este caso seleccionamos las siguientes dimenciones:
#
# * Mes de publicación
# * Pagado
# * Alcance total de publicación por vida
# * Usuarios comprometidos de por vida
# * Consumidores totales por vida
# * Alcance de publicaciones en personas a las que le gusta la página
# * Total interacciones
#
# Y las cruzamos para ver si nos dan alguna pista de su agrupación y la relación con su `Tipo`

# %%
sb.pairplot(ds.dropna(), hue='Tipo',size=4,vars=['Mes de publicación','Pagado','Alcance total de publicación por vida','Usuarios comprometidos de por vida','Consumidores totales por vida','Alcance de publicaciones en personas a las que le gusta la página','Total interacciones'],kind='scatter')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:1969: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Concretamos la estructura de datos que utilizaremos para alimentar el algoritmo.

# %%
ds.replace([np.inf, -np.inf], np.nan, inplace=True)
ds.fillna(0, inplace=True)
X = np.array(ds[['Mes de publicación','Pagado','Alcance total de publicación por vida','Usuarios comprometidos de por vida','Consumidores totales por vida','Alcance de publicaciones en personas a las que le gusta la página','Total interacciones']])
y = np.array(ds['Tipo'])

# %% [markdown]
# Veremos una gráfica en 3D representando le tipo.

# %%
fig = plt.figure()
ax = Axes3D(fig)

ax.scatter(X[:, 0], X[:, 1], X[:, 2], s=60)

# %% [markdown]
# #### Obtener el valor de K
#
# Vamos a hallar el valor de `K` haciendo una gráfica e intentando hallar el “punto de codo”. Este es nuestro resultado:

# %%
Nc = range(1, 20)
kmeans = [KMeans(n_clusters=i) for i in Nc]
kmeans
score = [kmeans[i].fit(X).score(X) for i in range(len(kmeans))]
score
plt.plot(Nc,score)
plt.xlabel('Número de Clusters')
plt.ylabel('Puntuación')
plt.title('Curva del codo')
plt.show()

# %% [markdown]
# Ejecutamos el algoritmo K-Means para 3 clustes y obtenemos las etiquetas y los centroids.

# %%
kmeans = KMeans(n_clusters=3).fit(X)
centroids = kmeans.cluster_centers_
print(centroids)
# Out:
# [[7.14285714e+00 2.50585480e-01 6.46081499e+03 7.44742389e+02
#   6.68077283e+02 4.20756909e+03 1.47822014e+02]
#  [6.67741935e+00 4.19354839e-01 4.51770323e+04 1.68420968e+03
#   1.34656452e+03 1.98464516e+04 5.19516129e+02]
#  [5.00000000e+00 5.45454545e-01 1.26539636e+05 3.43145455e+03
#   2.78454545e+03 2.41483636e+04 9.75454545e+02]]

# %% [markdown]
# Ahora veremos esto en una gráfica 3D con colores para los grupos y veremos si se diferencian.

# %%
# Prediting the clusters
labels = kmeans.predict(X)

#Getting the cluster centers
C = kmeans.cluster_centers_
colores=['red','green','blue']
asignar=[]
for row in labels:
    asignar.append(colores[row])

fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=asignar,s=60)
ax.scatter(C[:, 0], C[:, 1], C[:, 2], marker='*', c=colores, s=1000)

# %% [markdown]
# Haremos 3 gráficas en 2 dimensiones con las proyecciones a partir de nuestra gráfica 3D para que nos ayude a visualizar los grupos y su clasificación:

# %%
# Getting the values and plotting it
f1 = ds['Mes de publicación'].values
f2 = ds['Pagado'].values
 
plt.scatter(f1, f2, c=asignar, s=70)
plt.scatter(C[:, 0], C[:, 1], marker='*', c=colores, s=1000)
plt.show()

# %%
# Getting the values and plotting it
f1 = ds['Mes de publicación'].values
f2 = ds['Alcance total de publicación por vida'].values
 
plt.scatter(f1, f2, c=asignar, s=70)
plt.scatter(C[:, 0], C[:, 2], marker='*', c=colores, s=1000)
plt.show()

# %%
# Getting the values and plotting it
f1 = ds['Pagado'].values
f2 = ds['Alcance total de publicación por vida'].values
 
plt.scatter(f1, f2, c=asignar, s=70)
plt.scatter(C[:, 0], C[:, 2], marker='*', c=colores, s=1000)
plt.show()

# %%
copy =  pd.DataFrame()
copy['Tipo']=ds['Tipo'].values
copy['label'] = labels;
cantidadGrupo =  pd.DataFrame()
cantidadGrupo['Color']=colores
cantidadGrupo['Cantidad']=copy.groupby('label').size()
cantidadGrupo
# Out:
#    Color  Cantidad
# 0    red       427
# 1  green        62
# 2   blue        11

# %%
#vemos el representante del grupo, el usuario cercano a su centroid
closest, _ = pairwise_distances_argmin_min(kmeans.cluster_centers_, X)
closest
# Out:
# array([342, 401, 380])

# %%
tipos = ds['Tipo'].values
for row in closest:
  print(tipos[row])
# Out:
# Photo
# Photo
# Photo

# %% [markdown]
# # 5. Conclusiones

# %% [markdown]
# *   Para asegurar un entrenamiento adecuado de los algoritmos se debe cuidar que los datos del dataset tengan muestras de los tipos de interes en igual cantidad, dado que al predominar un tipo de datos por sobre los otros, estamos dando una señal de "preferencia" al algoritmo
# *   Cuando un tipo de solución de IA no es suficiente para el problema que se intenta solucionar, se debe considerar recurir a otras técnica. En esta caso, al aplicar minería de datos al dataset, el tipo de publicación mejora el alcance a consumidores de por vida en una publicación.
# *    En conjunto, para la toma de desiciones, en este caso, no se debe restar importancia al Análisis exploratorio de datos ya que con eso se tiene criterios de aceptación que responden al problema.
